# %%
import pandas as pd
import matplotlib.pyplot as plt
from risk import *
from returns import *
from quandler import Quandler

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
plt.rcParams["figure.figsize"] = [18, 10]

C= "#C79810"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
q = Quandler()
df = q.get_ind_returns()

# %%
drawdown(df["Food"]).plot.line()

# %%
var_summary(df).sort_values(by="corfish").plot.bar()

# %%
df.aggregate(sharpe_ratio, n=12).sort_values().plot.bar(color=C)

# %%
df["2000":].aggregate(sharpe_ratio,n=12).sort_values().plot.bar(color="#C79810")

# %%
er = df["1995":"2000"].aggregate(annualized_returns,n=12).sort_values()
er.plot.bar(color=C)

# %%
cov_mat = df["1995":"2000"].cov()
plt.matshow(cov_mat)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.show()
