# %%
from tvm import *  
from bonds import *
import  pytest
import numpy_financial as npf
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from quandler import Quandler

# %%
par_rates = np.linspace(0.1,1.9,100)
ytm = [ bond_ytm(1000,par_rate, 0.0925, 10)  for par_rate in par_rates  ]
plt.plot(ytm,par_rates)    
plt.show()

# %%
q = Quandler()
df = q.read(['ICET7IN'], gte='2001-01-11', lte='2020-08-10', dropna=False)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
